# %%
# Dependencies
from matplotlib import pyplot as plt
from scipy import stats
import numpy as np
import pandas as pd

from scipy.stats import linregress
from sklearn import datasets

# %%
# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# %%
# File to Load (Remember to Change These)
ratones = pd.read_csv("mouse_drug_data.csv") 
tratamiento = pd.read_csv("clinicaltrial_data.csv")

# %%
# Juntas las dos bases
tabla1 = pd.merge(tratamiento,ratones, on="Mouse ID",how="outer")

# %%
# Store the Mean Tumor Volume Data Grouped by Drug and Timepoint 

base=tabla1.groupby(["Drug","Timepoint"]).mean()["Tumor Volume (mm3)"].rename("Volumen")

# Convert to DataFrame
droga_dias = pd.DataFrame(base).reset_index()

# Preview DataFrame
droga_dias.head()
# Out:
#         Drug  Timepoint    Volumen
# 0  Capomulin          0  45.000000
# 1  Capomulin          5  44.266086
# 2  Capomulin         10  43.084291
# 3  Capomulin         15  42.064317
# 4  Capomulin         20  40.716325

# %%
# Store the Standard Error of Tumor Volumes Grouped by Drug and Timepoint
volumen_error = tabla1.groupby(["Drug","Timepoint"])["Tumor Volume (mm3)"].sem()
# Convert to DataFrame
volumen_error_data = pd.DataFrame(volumen_error).reset_index()
# Preview DataFrame
volumen_error_data .head()
# Out:
#         Drug  Timepoint  Tumor Volume (mm3)
# 0  Capomulin          0            0.000000
# 1  Capomulin          5            0.448593
# 2  Capomulin         10            0.702684
# 3  Capomulin         15            0.838617
# 4  Capomulin         20            0.909731

# %%
# Minor Data Munging to Re-Format the Data Frames
Tabla_Droga_timepoint = droga_dias.pivot(index = "Timepoint", columns ="Drug", values ="Volumen" ) 
 
# Preview that Reformatting worked
Tabla_Droga_timepoint
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
# 25         39.939528  54.287674  55.715252  57.678982  56.731968  57.482574
# 30         38.769339  56.769517  58.299397  60.994507  59.559509  59.809063
# 35         37.816839  58.827548  60.742461  63.371686  62.685087  62.420615
# 40         36.958001  61.467895  63.162824  66.068580  65.600754  65.052675
# 45         36.236114  64.132421  65.755562  70.662958  69.265506  68.084082
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# 5          47.248967  43.944859  47.527452  46.851818
# 10         49.101541  42.531957  49.463844  48.689881
# 15         51.067318  41.495061  51.529409  50.779059
# 20         53.346737  40.238325  54.067395  53.170334
# 25         55.504138  38.974300  56.166123  55.432935
# 30         58.196374  38.703137  59.826738  57.713531
# 35         60.350199  37.451996  62.440699  60.089372
# 40         63.045537  36.574081  65.356386  62.916692
# 45         66.258529  34.955595  68.438310  65.960888

# %%
# Generate the Plot (with Error Bars)
droga1 = volumen_error_data.loc[Tumor_response_data_error["Drug"] == "Capomulin", "Tumor Volume (mm3)"]
droga2 = volumen_error_data.loc[Tumor_response_data_error["Drug"] == "Ceftamin", "Tumor Volume (mm3)"]
droga3 = volumen_error_data.loc[Tumor_response_data_error["Drug"] == "Infubinol", "Tumor Volume (mm3)"]
droga4 = volumen_error_data.loc[Tumor_response_data_error["Drug"] == "Placebo", "Tumor Volume (mm3)"]
Time = [0, 5, 10, 15, 20, 25, 30, 35, 40, 45]
plt.errorbar(Time, Tabla_Droga_timepoint["Capomulin"] , yerr= droga1, label= "Capomulin", marker= "o", color="red")
plt.errorbar(Time, Tabla_Droga_timepoint["Ceftamin"] , yerr= droga2, label= "Ceftamin",   marker= "^", color="blue")
plt.errorbar(Time, Tabla_Droga_timepoint["Infubinol"] , yerr= droga3, label= "Infubinol", marker= "D", color="black")
plt.errorbar(Time, Tabla_Droga_timepoint["Placebo"] , yerr= droga4 , label= "Placebo",    marker= "s", color="green")
plt.legend()
plt.title("Tamaño del tumor según Tratamiento ")
plt.xlabel("Días")
plt.ylabel("Tamaño(mm3)")
plt.grid()
# Save the Figure
